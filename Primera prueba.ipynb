# %%
import pandas as pd
import numpy as np
import requests as rq
from shapely.geometry import Point
import geopandas as gpd
import re
import os

# %%
import geopandas as gpd

# %%
os.listdir("../ih_datamadpt1121_project_m1/200215-0-instalaciones-deportivas.csv")
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '200215-0-instalaciones-deportivas.csv',
#  'Bicipark.json',
#  'Estaciones.json',
#  'modules',
#  'Primera prueba.ipynb',
#  'README.md']

# %%
instalaciones_dep_data= pd.read_csv("../ih_datamadpt1121_project_m1/200215-0-instalaciones-deportivas.csv", sep=';')
instalaciones_dep_data
# Out:
#            PK                                             NOMBRE  \
# 0    11353987  Instalación Deportiva  Básica Embalse de San Juan
# 1     6344681       Instalación Deportiva Básica Alto del Retiro
# 2    11350944  Instalación Deportiva Básica Avenida de Cerro ...
# 3    11350990  Instalación Deportiva Básica Avenida de las Su...
# 4    11350948  Instalación Deportiva Básica Avenida del Ensan...
# ..        ...                                                ...
# 508   6280408  Instalación Deportiva Municipal Rocódromo 'Roc...
# 509     38383  Instalación deportiva municipal básica Campo d...
# 510  10967962                Parque Lineal UZI 0.06 Arroyofresno
# 511  10967954                    Pista de Patinaje Paco de Lucía
# 512  10967959      Pista de petanca Centro de Mayores La Vaguada
#
#      DESCRIPCION-ENTIDAD                                     HORARIO  \
# 0                    NaN                                         NaN
# ...

# %%
instalaciones_dep_data=instalaciones_dep_data.drop(['PK','DESCRIPCION-ENTIDAD', 'HORARIO', 'EQUIPAMIENTO','BARRIO','Unnamed: 30', 'TRANSPORTE', 'DESCRIPCION', 'TIPO-NUM','ACCESIBILIDAD', 'CONTENT-URL','TELEFONO','FAX','EMAIL', 'TIPO', 'CODIGO-POSTAL','LOCALIDAD','PROVINCIA','DISTRITO','ORIENTACION','PLANTA','PUERTA', 'ESCALERAS'], 1)
instalaciones_dep_data
# Out:
# C:\Users\Diego Merello\miniconda3\envs\project_1\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                                                 NOMBRE  \
# 0    Instalación Deportiva  Básica Embalse de San Juan
# 1         Instalación Deportiva Básica Alto del Retiro
# 2    Instalación Deportiva Básica Avenida de Cerro ...
# 3    Instalación Deportiva Básica Avenida de las Su...
# 4    Instalación Deportiva Básica Avenida del Ensan...
# ..                                                 ...
# 508  Instalación Deportiva Municipal Rocódromo 'Roc...
# 509  Instalación deportiva municipal básica Campo d...
# 510                Parque Lineal UZI 0.06 Arroyofresno
# 511                    Pista de Patinaje Paco de Lucía
# 512      Pista de petanca Centro de Mayores La Vaguada
#
# ...

# %%
instalaciones_dep_data['NOMBRE-VIA']=instalaciones_dep_data['NOMBRE-VIA'].str.capitalize()
instalaciones_dep_data['CLASE-VIAL']=instalaciones_dep_data['CLASE-VIAL'].str.capitalize()
instalaciones_dep_data['NUM'] = instalaciones_dep_data['NUM'].replace(np.nan, 'S/N')
instalaciones_dep_data['Type of Place'] = "Instalación Deportiva"
instalaciones_dep_data['Place adress']=instalaciones_dep_data['CLASE-VIAL']+ ' ' + instalaciones_dep_data['NOMBRE-VIA'] + ', '+ instalaciones_dep_data['NUM'].astype(str)
instalaciones_dep_data
# Out:
#                                                 NOMBRE  \
# 0    Instalación Deportiva  Básica Embalse de San Juan
# 1         Instalación Deportiva Básica Alto del Retiro
# 2    Instalación Deportiva Básica Avenida de Cerro ...
# 3    Instalación Deportiva Básica Avenida de las Su...
# 4    Instalación Deportiva Básica Avenida del Ensan...
# ..                                                 ...
# 508  Instalación Deportiva Municipal Rocódromo 'Roc...
# 509  Instalación deportiva municipal básica Campo d...
# 510                Parque Lineal UZI 0.06 Arroyofresno
# 511                    Pista de Patinaje Paco de Lucía
# 512      Pista de petanca Centro de Mayores La Vaguada
#
#                  NOMBRE-VIA CLASE-VIAL  NUM  COORDENADA-X  COORDENADA-Y  \
# 0       Embalse de san juan      Calle    1      449213.0     4468179.0
# 1           Alto del retiro      Calle   13      450057.0     4468715.0
# 2              Cerro milano    Avenida    1      447502.0     4468855.0
# ...

# %%
bicimad= pd.read_json("../ih_datamadpt1121_project_m1/Estaciones.json")
bicimad
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ...
